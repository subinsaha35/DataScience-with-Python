# %%
# IMPORTING PANDAS
import pandas as pd

# %%
# LOADING DATASET 
petroleum= pd.read_csv(r"C:\Users\Subin\Downloads/Petroleum.csv")

# %%
# DATA SUB-SETTING
petroleum.head()
# Out:
#   Petroleum Products   2011-12 (MMTPA)   2012-13 (MMTPA)   2013-14 (MMTPA)   \
# 0                 LPG             15300             16986             18363
# 1                  MS             14993             16091             17527
# 2         NAPHTHA/NGL             11105             12353             11417
# 3                 ATF              5396              6009              6587
# 4                 SKO              8229              7949              7631
#
#    2014-15 (MMTPA)   2015-16 (MMTPA)   2016-17 (MMTPA)
# 0             19675             20857             21831
# 1             19083             20766             22588
# 2             11417             11022             11022
# 3              7202              7849              8540
# 4              7326              7033              6751

# %%
# IMPORTING MATPLOTLIB AND SEABORN

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Function that enables graph rendered in the Jupyter Notebook

# %matplotlib inline

# %%
# SEABORN THEME

sns.set(style="whitegrid")

# %%
#HISTOGRAM PLOT

petroleum= pd.read_csv(r"C:\Users\Subin\Downloads/Petroleum.csv")
sns.histplot(data=petroleum)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# BOXPLOT

petroleum= pd.read_csv(r"C:\Users\Subin\Downloads/Petroleum.csv")
ax = sns.boxplot(data=petroleum, orient="h", palette="Set2")

# %%
# SCATTER PLOT
petroleum= pd.read_csv(r"C:\Users\Subin\Downloads/Petroleum.csv")
sns.relplot(data=petroleum)
